# %%
from data_extractor import DataExtractor as de

query = de.set_query()

# %%
de.get_cards_info(query)

# %%
de.get_locations(query)

# %%
de.location(query)

# %%
de.get_locations_info(query)

# %%
de.get_seasons_info(query)

# %%
de.get_leaderboards(query)
